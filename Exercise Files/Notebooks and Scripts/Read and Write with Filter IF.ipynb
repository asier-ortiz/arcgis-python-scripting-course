# %%
inFile = open(r'C:\Users\linkedin\Desktop\Exercise Files\GISData\DataFile.csv','r')
outFile = open(r'C:\Users\linkedin\Desktop\Exercise Files\GISData\CrudeOilTanks.csv','w')

strColHeaders = inFile.readline()
print (strColHeaders)
outFile.write(strColHeaders)

recCount = 0
for eachRec in inFile:
    listRec = eachRec.split(",")
    if (listRec[2] == 'Crude'):
        recCount = recCount + 1
        print (recCount,":",eachRec)
        outFile.write(eachRec)
print (recCount,"records written.")

inFile.close()
outFile.close()
# Out:
# OID_,STATUS,TYPE,LAT,LON
#
# 1 : 212,Active,Crude,29.724893150000000,-95.01464489
#
# 2 : 213,Active,Crude,29.724419019999999,-95.01540775
#
# 3 : 214,Active,Crude,29.723989440000000,-95.0162183
#
# 4 : 217,Active,Crude,29.724693479999999,-95.01676002
#
# 5 : 218,Active,Crude,29.725137730000000,-95.01596548
#
# 6 : 221,Active,Crude,29.726761830000001,-95.01493523
#
# 7 : 222,Active,Crude,29.726318630000002,-95.01572234
#
# 8 : 223,Active,Crude,29.725812820000002,-95.0164974
#
# 9 : 224,Active,Crude,29.727052820000001,-95.01631409
#
# 10 : 225,Active,Crude,29.726588220000000,-95.01707659
#
# 11 : 226,Active,Crude,29.726129510000000,-95.0178717
#
# 12 : 227,Active,Crude,29.726849020000000,-95.01845663
#
# 13 : 228,Active,Crude,29.725042580000000,-95.01816588
#
# 14 : 229,Active,Crude,29.727541760000001,-95.01636986
#
# 15 : 230,Active,Crude,29.727824920000000,-95.01593188
#
# 16 : 231,Active,Crude,29.728014600000002,-95.01556323
#
# ...
